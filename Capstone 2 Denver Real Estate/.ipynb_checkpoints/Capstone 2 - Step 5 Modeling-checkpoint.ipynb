# %% [markdown]
# This notebook contains the work for Step 4 of the Data Science Method:
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
# 3.   Exploratory Data Analysis
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features</b>
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
#
# <b>5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model</b>
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# ### STEP 4: Pre-processing and Training Data Development

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from scipy.stats import chi2_contingency
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.svm import SVR
from sklearn.metrics import r2_score, explained_variance_score,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# %%
# set options
pd.set_option('display.max_rows', 1500)

# %%
# load the data saved from step 3
df=pd.read_csv('data\step3_output.csv')
df.head()
# Out:
# C:\Users\Nancy\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     SCHEDNUM_x  RECEPTION_NUM INSTRUMENT  SALE_YEAR  SALE_MONTHDAY  \
# 0  14101001000     2008138043         WD       2008            703
# 1  14101001000     2009074518         WD       2009            605
# 2  14101001000     2015157653         WD       2015           1102
# 3  14101001000     2009002129         WD       2008           1024
# 4  14101002000     2010094573         WD       2010            823
#
#    RECEPTION_DATE  SALE_PRICE                GRANTOR                GRANTEE  \
# 0        20081008        10.0       ATKINSON,RUSSELL     DREAM BUILDERS LLC
# 1        20090615    299000.0       ATKINSON,RUSSELL  PADBURY,CHRISTOPHER R
# 2        20151109    415000.0  PADBURY,CHRISTOPHER R   MACIEL,HORACIO PEREZ
# 3        20090108        10.0     DREAM BUILDERS LLC       ATKINSON,RUSSELL
# 4        20100824    350000.0       SHEARON,MARK H &         EFREM,TEWEDROS
#
#   CLASS  ...  UNITS  ASMT_APPR_LAND TOTAL_VALUE  ASDLAND ASSESS_VALUE  \
# 0     R  ...      1          103000      530200     7365        37910
# 1     R  ...      1          103000      530200     7365        37910
# 2     R  ...      1          103000      530200     7365        37910
# 3     R  ...      1          103000      530200     7365        37910
# 4     R  ...      1           90400      572600     6464        40941
#
#    ASMT_TAXABLE  ASMT_EXEMPT_AMT     NBHD_1_CN_y  \
# 0         37920                0  N GREEN VALLEY
# 1         37920                0  N GREEN VALLEY
# 2         37920                0  N GREEN VALLEY
# 3         37920                0  N GREEN VALLEY
# 4         40940                0  N GREEN VALLEY
#
#                     LEGL_DESCRIPTION IMPROVE_VALUE
# 0  GREEN VALLEY RANCH FLG #36 B1  L1        427200
# 1  GREEN VALLEY RANCH FLG #36 B1  L1        427200
# 2  GREEN VALLEY RANCH FLG #36 B1  L1        427200
# 3  GREEN VALLEY RANCH FLG #36 B1  L1        427200
# 4  GREEN VALLEY RANCH FLG #36 B1  L2        482200
#
# [5 rows x 60 columns]

# %% [markdown]
# ## Listing of fields, arranged in groups with decision about how to handle fields

# %% [markdown]
# |Field|type|group|definition|notes|
# |---|---|---|---|---|
# |CCAGE_RM|float64|age|Remodel Year||
# |CCYRBLT|float64|age|Year Built||
# |RECEPTION_DATE|int64|date|Clerk & Recorder's Reception Date|drop|
# |SALE_MONTHDAY|int64|date|Sale Month/Day||
# |SALE_YEAR|int64|date|Sale Year||
# |PIN|int64|id|Assessor's Property Identification Number|drop|
# |RECEPTION_NUM|int64|id|Input Key|drop|
# |SCHEDNUM_x|int64|id|Input Key|drop|
# |CO_OWNER|object|ignore|Co-Owner|drop|
# |MKT_CLUS|float64|loc|||
# |NBHD_1_CN_x|object|loc|Neighborhood name - x|category|
# |NBHD_1_CN_y|object|loc|Neighborhood name - y|drop|
# |NBHD_1_x|int64|loc|Neighborhood code|ignore|
# |SITE_DIR|object|loc|Site Street Direction|ignore|
# |SITE_MODE|object|loc|Site Street Type|ignore|
# |SITE_MORE|object|loc|Site Unit Number|ignore|
# |SITE_NAME|object|loc|Site Street Name|ignore|
# |SITE_NBR|int64|loc|Site Street Number|ignore|
# |TAX_DIST|object|loc|Tax District|category, ignore?|
# |ZONE10|object|loc|Zone|category, ignore?|
# |CD|int64|other|Building Number|drop|
# |CLASS|object|other|#N/A|drop|
# |D_CLASS|int64|other|Property Use Class|category, ignore?|
# |D_CLASS_CN_x|object|other|Property Use Class Definition - x|drop|
# |D_CLASS_CN_y|object|other|Property Use Class Definition - y|drop|
# |GRANTEE|object|other|??|drop|
# |GRANTOR|object|other|??|drop|
# |INSTRUMENT|object|other|??|drop|
# |LEGL_DESCRIPTION|object|other|Description of the parcel per the deed |drop|
# |PROP_CLASS|int64|other|Property Class(ASMT-PROP-CODE)|only select 1112|
# |PROPERTY_CLASS|object|other|Property Class Description|drop|
# |STYLE_CN|object|other|Architecture Style Code Definition|similar to STORY but does not agree|
# |OWNER|object|owner|Owner|drop|
# |OWNER_APT|object|owner|Street Mailing Unit Number|drop|
# |OWNER_CITY|object|owner|Mailing City|drop|
# |OWNER_DIR|object|owner|Street Mailing Direction|drop|
# |OWNER_NUM|object|owner|Street Mailing Number|drop|
# |OWNER_ST|object|owner|Street Mailing Street Name|drop|
# |OWNER_STATE|object|owner|Mailing State|drop|
# |OWNER_TYPE|object|owner|Street Mailing Type|drop|
# |OWNER_ZIP|object|owner|Zip Code|drop|
# |AREA_ABG|int64|size|Above Grade Improvement Area||
# |BED_RMS|int64|size|Number of bedroom above grade||
# |BSMT_AREA|int64|size|Basement Square Footage||
# |FBSMT_SQFT|int64|size|Finished Basement Area||
# |FULL_B|float64|size|Total number of full baths||
# |GRD_AREA|int64|size|Garden Level Square Footage||
# |HLF_B|float64|size|Total number of half baths||
# |LAND_SQFT|float64|size|Land Area||
# |OFCARD|int64|size|Number of Buildings|drop|
# |STORY|int64|size|Stories||
# |UNITS|int64|size|Number of Units||
# |ASDLAND|int64|value|Assessed Land Value|drop|
# |ASMT_APPR_LAND|int64|value|Actual Land Value||
# |ASMT_EXEMPT_AMT|int64|value|Exempt Amount|drop|
# |ASMT_TAXABLE|int64|value|Taxable Amount|drop|
# |ASSESS_VALUE|int64|value|Assessed Total Value|drop|
# |IMPROVE_VALUE|int64|value|Calculated=Tot Val - Land||
# |SALE_PRICE|float64|value|Sale Price||
# |TOTAL_VALUE|int64|value|Actual Total Value|drop|

# %%
# only select PROP_CLASS = 1112 (Single Family Residential)
df = df[df.PROP_CLASS == 1112]

# %%
# instead of looking at the year the house was built (CCYRBLT), transform it to years since built
df = df.assign(AGE = df.SALE_YEAR-df.CCYRBLT)

# %%
# instead of looking at year of remodel (CCAGE_RM), transform it to years since remodel
df=df.assign(RM_AGE = df.SALE_YEAR-df.CCAGE_RM)
# if remodel year is after sale (RM_AGE will be negative), then reset RM_AGE to AGE
df.loc[df.RM_AGE < 0, 'RM_AGE'] = df.AGE
# set remodel age to home age if no remodel year is available
df.loc[df.CCAGE_RM == 0, 'RM_AGE'] = df.AGE

# %%
# show results of new columns
print(df.groupby(['SALE_YEAR','CCYRBLT','CCAGE_RM','AGE','RM_AGE']).size())
# Out:
# SALE_YEAR  CCYRBLT  CCAGE_RM  AGE    RM_AGE
# 2008       1876.0   0.0       132.0  132.0       1
#            1880.0   0.0       128.0  128.0       1
#                     2001.0    128.0  7.0         1
#            1881.0   0.0       127.0  127.0       2
#                     2012.0    127.0  127.0       1
#                                               ...
# 2020       2018.0   0.0       2.0    2.0        31
#                     2018.0    2.0    2.0        14
#                     2019.0    2.0    1.0         1
#            2019.0   0.0       1.0    1.0       171
#                     2019.0    1.0    1.0        18
# Length: 24363, dtype: int64

# %%
# drop columns that are not going to be used
df.drop(['RECEPTION_DATE', 'PIN', 'RECEPTION_NUM', 'SCHEDNUM_x', 'CO_OWNER', 'NBHD_1_CN_y', 'NBHD_1_x'
         , 'SITE_DIR', 'SITE_MODE', 'SITE_MORE', 'SITE_NAME', 'SITE_NBR', 'TAX_DIST', 'ZONE10', 'CD', 'CLASS'
         , 'D_CLASS', 'D_CLASS_CN_x', 'D_CLASS_CN_y', 'GRANTEE', 'GRANTOR', 'INSTRUMENT', 'LEGL_DESCRIPTION'
         , 'PROP_CLASS', 'PROPERTY_CLASS', 'STYLE_CN', 'OWNER', 'OWNER_APT', 'OWNER_CITY', 'OWNER_DIR', 'OWNER_NUM'
         , 'OWNER_ST', 'OWNER_STATE', 'OWNER_TYPE', 'OWNER_ZIP', 'OFCARD', 'ASDLAND', 'ASMT_EXEMPT_AMT'
         , 'ASMT_TAXABLE', 'ASSESS_VALUE', 'TOTAL_VALUE', 'CCYRBLT', 'CCAGE_RM'], axis=1, inplace=True)

# %%
# drop any rows with NaN values
df.dropna(inplace=True)

# %%
# change categorical values (NBHD_1_CN_x) to indicators
df_inds = pd.get_dummies(data=df, columns=['NBHD_1_CN_x'],drop_first=True)

# %%
df_inds.describe().T
# Out:
#                                   count           mean            std     min  \
# SALE_YEAR                      141505.0    2014.118434       3.506308  2008.0
# SALE_MONTHDAY                  141505.0     669.957351     328.937146   101.0
# SALE_PRICE                     141505.0  313035.398777  370151.400663     1.0
# MKT_CLUS                       141505.0      16.446479       9.742234     1.0
# LAND_SQFT                      141505.0    6518.791541    2813.477368     0.0
# AREA_ABG                       141505.0    1570.051242     823.710111   226.0
# BSMT_AREA                      141505.0     670.464104     569.504749     0.0
# FBSMT_SQFT                     141505.0     456.587174     507.854015     0.0
# GRD_AREA                       141505.0      33.882146     147.041963     0.0
# STORY                          141505.0       1.384050       0.529795     1.0
# BED_RMS                        141505.0       2.820289       0.823717     0.0
# FULL_B                         141505.0       2.136151       0.932042     0.0
# HLF_B                          141505.0       0.359146       0.521453     0.0
# UNITS                          141505.0       1.028826       0.292535     0.0
# ASMT_APPR_LAND                 141505.0  234415.256705  197605.138817     0.0
# IMPROVE_VALUE                  141505.0  337116.560454  271509.990577     0.0
# AGE                            141505.0      58.338780      36.080978   -11.0
# RM_AGE                         141505.0      29.428190      34.136936   -11.0
# NBHD_1_CN_x_ARAPAHOE SQUARE    141505.0       0.000198       0.014065     0.0
# NBHD_1_CN_x_ATHMAR PARK        141505.0       0.016862       0.128753     0.0
# NBHD_1_CN_x_AVONDALE           141505.0       0.002530       0.050235     0.0
# NBHD_1_CN_x_BAKER              141505.0       0.005413       0.073376     0.0
# NBHD_1_CN_x_BARNUM             141505.0       0.021985       0.146635     0.0
# NBHD_1_CN_x_BEAR VALLEY        141505.0       0.008120       0.089744     0.0
# NBHD_1_CN_x_BELCARO            141505.0       0.001420       0.037662     0.0
# NBHD_1_CN_x_BELMONT HTS        141505.0       0.001329       0.036426     0.0
# NBHD_1_CN_x_BERKELEY           141505.0       0.021992       0.146658     0.0
# NBHD_1_CN_x_BISCAYNE           141505.0       0.000827       0.028743     0.0
# NBHD_1_CN_x_BONNIE BRAE        141505.0       0.004466       0.066681     0.0
# NBHD_1_CN_x_BREAKERS           141505.0       0.000919       0.030296     0.0
# NBHD_1_CN_x_C GREEN VALLEY     141505.0       0.009180       0.095371     0.0
# NBHD_1_CN_x_CAPITOL HILL       141505.0       0.001039       0.032214     0.0
# NBHD_1_CN_x_CAPITOL HILL S     141505.0       0.001859       0.043071     0.0
# NBHD_1_CN_x_CENTRAL PARK       141505.0       0.000247       0.015725     0.0
# NBHD_1_CN_x_CHAFFEE PARK       141505.0       0.010558       0.102208     0.0
# NBHD_1_CN_x_CHEESMAN PARK      141505.0       0.003039       0.055041     0.0
# NBHD_1_CN_x_CHERMONT           141505.0       0.000473       0.021755     0.0
# NBHD_1_CN_x_CHERRY CREEK       141505.0       0.000657       0.025628     0.0
# NBHD_1_CN_x_CHERRY POINT       141505.0       0.001251       0.035345     0.0
# NBHD_1_CN_x_CIVIC CENTER       141505.0       0.000035       0.005944     0.0
# NBHD_1_CN_x_CLAYTON            141505.0       0.009745       0.098236     0.0
# NBHD_1_CN_x_COLE               141505.0       0.009378       0.096384     0.0
# NBHD_1_CN_x_COLLEGE VIEW       141505.0       0.007067       0.083768     0.0
# NBHD_1_CN_x_CONGRESS PARK      141505.0       0.006523       0.080500     0.0
# NBHD_1_CN_x_CORNERSTONE        141505.0       0.000396       0.019889     0.0
# NBHD_1_CN_x_CORY MERRILL       141505.0       0.017003       0.129282     0.0
# NBHD_1_CN_x_COUNTRY CLUB       141505.0       0.002283       0.047722     0.0
# NBHD_1_CN_x_CREEKVW/SUNSET     141505.0       0.000459       0.021428     0.0
# NBHD_1_CN_x_CRESTMOOR          141505.0       0.005717       0.075395     0.0
# NBHD_1_CN_x_CRESTMOOR E        141505.0       0.002664       0.051547     0.0
# NBHD_1_CN_x_CRESTRIDGE         141505.0       0.000346       0.018605     0.0
# NBHD_1_CN_x_CURTIS PARK        141505.0       0.004275       0.065247     0.0
# NBHD_1_CN_x_DARTMOUTH HTS      141505.0       0.001074       0.032757     0.0
# NBHD_1_CN_x_E COLFAX (N)       141505.0       0.010487       0.101869     0.0
# NBHD_1_CN_x_E COLFAX (S)       141505.0       0.007943       0.088770     0.0
# NBHD_1_CN_x_E HARVEY PARK      141505.0       0.012402       0.110674     0.0
# NBHD_1_CN_x_E HIGHLAND         141505.0       0.007180       0.084430     0.0
# NBHD_1_CN_x_E SLOANS LAKE      141505.0       0.005039       0.070805     0.0
# NBHD_1_CN_x_EAST BAY           141505.0       0.000770       0.027744     0.0
# NBHD_1_CN_x_FIVE POINTS        141505.0       0.001081       0.032864     0.0
# NBHD_1_CN_x_FORT LOGAN         141505.0       0.005229       0.072126     0.0
# NBHD_1_CN_x_GLENBROOK          141505.0       0.004318       0.065569     0.0
# NBHD_1_CN_x_GLOBEVILLE         141505.0       0.004813       0.069206     0.0
# NBHD_1_CN_x_GODSMAN            141505.0       0.008473       0.091659     0.0
# NBHD_1_CN_x_GOLDSMITH          141505.0       0.002346       0.048381     0.0
# NBHD_1_CN_x_GOLDSMITH  W       141505.0       0.000057       0.007519     0.0
# NBHD_1_CN_x_GRANT RN/MARST     141505.0       0.005675       0.075117     0.0
# NBHD_1_CN_x_GREEN VALLEY       141505.0       0.038677       0.192825     0.0
# NBHD_1_CN_x_GUN CLUB           141505.0       0.000466       0.021592     0.0
# NBHD_1_CN_x_HALE/MAYFAIR       141505.0       0.014643       0.120118     0.0
# NBHD_1_CN_x_HAMPDEN HTS E      141505.0       0.004495       0.066891     0.0
# NBHD_1_CN_x_HAMPDEN HTS W      141505.0       0.007060       0.083726     0.0
# NBHD_1_CN_x_HARVEY PARK        141505.0       0.015088       0.121903     0.0
# NBHD_1_CN_x_HIGHLAND           141505.0       0.008848       0.093646     0.0
# NBHD_1_CN_x_HILLTOP            141505.0       0.010219       0.100570     0.0
# NBHD_1_CN_x_HILLTOP 6TH AV     141505.0       0.000869       0.029470     0.0
# NBHD_1_CN_x_HILLTOP DOWNS      141505.0       0.000134       0.011587     0.0
# NBHD_1_CN_x_HOLLY HILLS        141505.0       0.000269       0.016385     0.0
# NBHD_1_CN_x_HOLLY RIDGE        141505.0       0.000594       0.024357     0.0
# NBHD_1_CN_x_HUTCH/WILLOW P     141505.0       0.000770       0.027744     0.0
# NBHD_1_CN_x_HUTCHINSON HLS     141505.0       0.003512       0.059160     0.0
# NBHD_1_CN_x_INDIAN CREEK       141505.0       0.000269       0.016385     0.0
# NBHD_1_CN_x_INSPIRATION PT     141505.0       0.002438       0.049317     0.0
# NBHD_1_CN_x_JEFFERSON PARK     141505.0       0.002021       0.044912     0.0
# NBHD_1_CN_x_LINCOLN PARK       141505.0       0.004784       0.069003     0.0
# NBHD_1_CN_x_LOWRY              141505.0       0.012417       0.110736     0.0
# NBHD_1_CN_x_LYNWOOD            141505.0       0.001230       0.035045     0.0
# NBHD_1_CN_x_MAR LEE            141505.0       0.022063       0.146888     0.0
# NBHD_1_CN_x_MONACO PKWY        141505.0       0.001145       0.033816     0.0
# NBHD_1_CN_x_MONTBELLO          141505.0       0.048627       0.215088     0.0
# NBHD_1_CN_x_MONTCLAIR          141505.0       0.007046       0.083643     0.0
# NBHD_1_CN_x_N CAPITOL HILL     141505.0       0.000367       0.019166     0.0
# NBHD_1_CN_x_N CHERRY CREEK     141505.0       0.001753       0.041827     0.0
# NBHD_1_CN_x_N CONGRESS PK      141505.0       0.005512       0.074039     0.0
# NBHD_1_CN_x_N COUNTRY CLUB     141505.0       0.003223       0.056676     0.0
# NBHD_1_CN_x_N GREEN VALLEY     141505.0       0.036889       0.188490     0.0
# NBHD_1_CN_x_N PARK HILL        141505.0       0.027200       0.162668     0.0
# NBHD_1_CN_x_N POLO CLUB        141505.0       0.001145       0.033816     0.0
# NBHD_1_CN_x_N SLOANS LAKE      141505.0       0.005328       0.072802     0.0
# NBHD_1_CN_x_N SPEER            141505.0       0.003965       0.062840     0.0
# NBHD_1_CN_x_N UNIVERSITY       141505.0       0.003187       0.056365     0.0
# NBHD_1_CN_x_NE PARK HILL       141505.0       0.012120       0.109421     0.0
# NBHD_1_CN_x_NORTHFIELD         141505.0       0.018289       0.133995     0.0
# NBHD_1_CN_x_OVERLAND           141505.0       0.004318       0.065569     0.0
# NBHD_1_CN_x_OVERLOOK           141505.0       0.001025       0.031995     0.0
# NBHD_1_CN_x_PARK FOREST        141505.0       0.000883       0.029708     0.0
# NBHD_1_CN_x_PARK HILL (N)      141505.0       0.012897       0.112831     0.0
# NBHD_1_CN_x_PARK HILL (S)      141505.0       0.012466       0.110953     0.0
# NBHD_1_CN_x_PARK VISTA         141505.0       0.002558       0.050514     0.0
# NBHD_1_CN_x_PARKFIELD          141505.0       0.010092       0.099949     0.0
# NBHD_1_CN_x_PARKWAY            141505.0       0.005760       0.075673     0.0
# NBHD_1_CN_x_PARKWEST           141505.0       0.003230       0.056738     0.0
# NBHD_1_CN_x_PINE RIDGE         141505.0       0.001166       0.034127     0.0
# NBHD_1_CN_x_PINE VALLEY        141505.0       0.001442       0.037942     0.0
# NBHD_1_CN_x_PINECREST          141505.0       0.001435       0.037849     0.0
# NBHD_1_CN_x_PINEHURST          141505.0       0.001364       0.036906     0.0
# NBHD_1_CN_x_PINEHURST ES S     141505.0       0.002502       0.049954     0.0
# NBHD_1_CN_x_PINEHURST ESTA     141505.0       0.000601       0.024502     0.0
# NBHD_1_CN_x_PLATTE PARK        141505.0       0.013067       0.113561     0.0
# NBHD_1_CN_x_POLO CLUB          141505.0       0.000353       0.018794     0.0
# NBHD_1_CN_x_POLO FIELD         141505.0       0.000622       0.024930     0.0
# NBHD_1_CN_x_POPLAR COVE        141505.0       0.000064       0.007975     0.0
# NBHD_1_CN_x_RANGE VIEW         141505.0       0.000671       0.025902     0.0
# NBHD_1_CN_x_REGIS              141505.0       0.008466       0.091622     0.0
# NBHD_1_CN_x_RIVER NORTH        141505.0       0.000177       0.013291     0.0
# NBHD_1_CN_x_ROSEDALE           141505.0       0.005364       0.073041     0.0
# NBHD_1_CN_x_RUBY HILL          141505.0       0.007887       0.088456     0.0
# NBHD_1_CN_x_S CHERRY CREEK     141505.0       0.000247       0.015725     0.0
# NBHD_1_CN_x_S CITY PARK        141505.0       0.002537       0.050305     0.0
# NBHD_1_CN_x_S COUNTRY CLUB     141505.0       0.000382       0.019531     0.0
# NBHD_1_CN_x_S HALE             141505.0       0.004770       0.068902     0.0
# NBHD_1_CN_x_S HARVEY PARK      141505.0       0.011130       0.104912     0.0
# NBHD_1_CN_x_S SPEER            141505.0       0.007053       0.083684     0.0
# NBHD_1_CN_x_S WASHINGTON PK    141505.0       0.002798       0.052827     0.0
# NBHD_1_CN_x_S. HILLTOP         141505.0       0.002996       0.054657     0.0
# NBHD_1_CN_x_SEVEN SPRINGS      141505.0       0.000643       0.025351     0.0
# NBHD_1_CN_x_SKYLAND            141505.0       0.008805       0.093423     0.0
# NBHD_1_CN_x_SLOANS LAKE        141505.0       0.006537       0.080587     0.0
# NBHD_1_CN_x_SOUTH PLATTE       141505.0       0.000021       0.004604     0.0
# NBHD_1_CN_x_SOUTHMOOR #1       141505.0       0.001399       0.037380     0.0
# NBHD_1_CN_x_SOUTHMOOR PARK     141505.0       0.002912       0.053880     0.0
# NBHD_1_CN_x_STAPLETON          141505.0       0.032253       0.176673     0.0
# NBHD_1_CN_x_STOKES             141505.0       0.001300       0.036036     0.0
# NBHD_1_CN_x_SUMMERFIELD        141505.0       0.000346       0.018605     0.0
# NBHD_1_CN_x_SUN VALLEY         141505.0       0.001131       0.033607     0.0
# NBHD_1_CN_x_SUNNYSIDE          141505.0       0.011286       0.105634     0.0
# NBHD_1_CN_x_SWANSEA            141505.0       0.001131       0.033607     0.0
# NBHD_1_CN_x_SWANSEA (N)        141505.0       0.003993       0.063062     0.0
# NBHD_1_CN_x_SWANSEA (S)        141505.0       0.002820       0.053026     0.0
# NBHD_1_CN_x_TAMARAC HILLS      141505.0       0.000431       0.020758     0.0
# NBHD_1_CN_x_THOMAS PLACE       141505.0       0.000014       0.003759     0.0
# NBHD_1_CN_x_UNIVERSITY         141505.0       0.014042       0.117664     0.0
# NBHD_1_CN_x_UNIVERSITY HLS     141505.0       0.017823       0.132307     0.0
# NBHD_1_CN_x_UNIVERSITY PK      141505.0       0.010077       0.099879     0.0
# NBHD_1_CN_x_UNIVERSITY S       141505.0       0.003950       0.062728     0.0
# NBHD_1_CN_x_VALVERDE           141505.0       0.004537       0.067204     0.0
# NBHD_1_CN_x_VILLA PARK         141505.0       0.012996       0.113257     0.0
# NBHD_1_CN_x_VILLAS CHRY HL     141505.0       0.000579       0.024066     0.0
# NBHD_1_CN_x_VIRGINIA VALE      141505.0       0.004721       0.068545     0.0
# NBHD_1_CN_x_VIRGINIA VILL      141505.0       0.022289       0.147622     0.0
# NBHD_1_CN_x_W BAKER            141505.0       0.004629       0.067878     0.0
# NBHD_1_CN_x_W CITY PARK        141505.0       0.002071       0.045457     0.0
# NBHD_1_CN_x_W COLFAX           141505.0       0.002445       0.049388     0.0
# NBHD_1_CN_x_W HIGHLAND         141505.0       0.016261       0.126478     0.0
# NBHD_1_CN_x_W HIGHLAND / HGV   141505.0       0.002226       0.047129     0.0
# NBHD_1_CN_x_W WASHINGTON PARK  141505.0       0.003512       0.059160     0.0
# NBHD_1_CN_x_W WASHINGTON PK    141505.0       0.011349       0.105928     0.0
# NBHD_1_CN_x_WASHINGTON         141505.0       0.003088       0.055486     0.0
# NBHD_1_CN_x_WASHINGTON PK      141505.0       0.015660       0.124158     0.0
# NBHD_1_CN_x_WELLSHIRE EAST     141505.0       0.001329       0.036426     0.0
# NBHD_1_CN_x_WESTBRIDGE         141505.0       0.002014       0.044833     0.0
# NBHD_1_CN_x_WESTWOOD           141505.0       0.019688       0.138928     0.0
# NBHD_1_CN_x_WHITTIER           141505.0       0.014869       0.121028     0.0
# NBHD_1_CN_x_WILLOW POINT E     141505.0       0.001003       0.031662     0.0
# NBHD_1_CN_x_WLSHR/S HILLS      141505.0       0.007618       0.086949     0.0
# NBHD_1_CN_x_ZUNI PARK          141505.0       0.011272       0.105569     0.0
#
#                                     25%       50%       75%         max
# SALE_YEAR                        2011.0    2014.0    2017.0      2020.0
# SALE_MONTHDAY                     412.0     629.0     926.0      1231.0
# SALE_PRICE                      85700.0  265000.0  430000.0  49500000.0
# MKT_CLUS                            8.0      16.0      24.0        54.0
# LAND_SQFT                        4846.0    6250.0    7380.0    282000.0
# AREA_ABG                         1000.0    1305.0    1904.0     16778.0
# BSMT_AREA                           0.0     747.0    1058.0      8712.0
# FBSMT_SQFT                          0.0     316.0     851.0      8276.0
# GRD_AREA                            0.0       0.0       0.0      2875.0
# STORY                               1.0       1.0       2.0         3.0
# BED_RMS                             2.0       3.0       3.0        15.0
# FULL_B                              2.0       2.0       3.0         9.0
# HLF_B                               0.0       0.0       1.0         6.0
# UNITS                               1.0       1.0       1.0        13.0
# ASMT_APPR_LAND                  91600.0  176200.0  328100.0   7750000.0
# IMPROVE_VALUE                  209400.0  270400.0  374900.0   6890400.0
# AGE                                30.0      61.0      84.0       142.0
# RM_AGE                              1.0      12.0      57.0       139.0
# NBHD_1_CN_x_ARAPAHOE SQUARE         0.0       0.0       0.0         1.0
# NBHD_1_CN_x_ATHMAR PARK             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_AVONDALE                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_BAKER                   0.0       0.0       0.0         1.0
# NBHD_1_CN_x_BARNUM                  0.0       0.0       0.0         1.0
# NBHD_1_CN_x_BEAR VALLEY             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_BELCARO                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_BELMONT HTS             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_BERKELEY                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_BISCAYNE                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_BONNIE BRAE             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_BREAKERS                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_C GREEN VALLEY          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CAPITOL HILL            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CAPITOL HILL S          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CENTRAL PARK            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CHAFFEE PARK            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CHEESMAN PARK           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CHERMONT                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CHERRY CREEK            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CHERRY POINT            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CIVIC CENTER            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CLAYTON                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_COLE                    0.0       0.0       0.0         1.0
# NBHD_1_CN_x_COLLEGE VIEW            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CONGRESS PARK           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CORNERSTONE             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CORY MERRILL            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_COUNTRY CLUB            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CREEKVW/SUNSET          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CRESTMOOR               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CRESTMOOR E             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CRESTRIDGE              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_CURTIS PARK             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_DARTMOUTH HTS           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_E COLFAX (N)            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_E COLFAX (S)            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_E HARVEY PARK           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_E HIGHLAND              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_E SLOANS LAKE           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_EAST BAY                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_FIVE POINTS             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_FORT LOGAN              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_GLENBROOK               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_GLOBEVILLE              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_GODSMAN                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_GOLDSMITH               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_GOLDSMITH  W            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_GRANT RN/MARST          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_GREEN VALLEY            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_GUN CLUB                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HALE/MAYFAIR            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HAMPDEN HTS E           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HAMPDEN HTS W           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HARVEY PARK             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HIGHLAND                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HILLTOP                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HILLTOP 6TH AV          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HILLTOP DOWNS           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HOLLY HILLS             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HOLLY RIDGE             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HUTCH/WILLOW P          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_HUTCHINSON HLS          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_INDIAN CREEK            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_INSPIRATION PT          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_JEFFERSON PARK          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_LINCOLN PARK            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_LOWRY                   0.0       0.0       0.0         1.0
# NBHD_1_CN_x_LYNWOOD                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_MAR LEE                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_MONACO PKWY             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_MONTBELLO               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_MONTCLAIR               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N CAPITOL HILL          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N CHERRY CREEK          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N CONGRESS PK           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N COUNTRY CLUB          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N GREEN VALLEY          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N PARK HILL             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N POLO CLUB             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N SLOANS LAKE           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N SPEER                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_N UNIVERSITY            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_NE PARK HILL            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_NORTHFIELD              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_OVERLAND                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_OVERLOOK                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PARK FOREST             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PARK HILL (N)           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PARK HILL (S)           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PARK VISTA              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PARKFIELD               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PARKWAY                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PARKWEST                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PINE RIDGE              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PINE VALLEY             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PINECREST               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PINEHURST               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PINEHURST ES S          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PINEHURST ESTA          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_PLATTE PARK             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_POLO CLUB               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_POLO FIELD              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_POPLAR COVE             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_RANGE VIEW              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_REGIS                   0.0       0.0       0.0         1.0
# NBHD_1_CN_x_RIVER NORTH             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_ROSEDALE                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_RUBY HILL               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_S CHERRY CREEK          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_S CITY PARK             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_S COUNTRY CLUB          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_S HALE                  0.0       0.0       0.0         1.0
# NBHD_1_CN_x_S HARVEY PARK           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_S SPEER                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_S WASHINGTON PK         0.0       0.0       0.0         1.0
# NBHD_1_CN_x_S. HILLTOP              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SEVEN SPRINGS           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SKYLAND                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SLOANS LAKE             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SOUTH PLATTE            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SOUTHMOOR #1            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SOUTHMOOR PARK          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_STAPLETON               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_STOKES                  0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SUMMERFIELD             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SUN VALLEY              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SUNNYSIDE               0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SWANSEA                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SWANSEA (N)             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_SWANSEA (S)             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_TAMARAC HILLS           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_THOMAS PLACE            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_UNIVERSITY              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_UNIVERSITY HLS          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_UNIVERSITY PK           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_UNIVERSITY S            0.0       0.0       0.0         1.0
# NBHD_1_CN_x_VALVERDE                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_VILLA PARK              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_VILLAS CHRY HL          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_VIRGINIA VALE           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_VIRGINIA VILL           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_W BAKER                 0.0       0.0       0.0         1.0
# NBHD_1_CN_x_W CITY PARK             0.0       0.0       0.0         1.0
# NBHD_1_CN_x_W COLFAX                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_W HIGHLAND              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_W HIGHLAND / HGV        0.0       0.0       0.0         1.0
# NBHD_1_CN_x_W WASHINGTON PARK       0.0       0.0       0.0         1.0
# NBHD_1_CN_x_W WASHINGTON PK         0.0       0.0       0.0         1.0
# NBHD_1_CN_x_WASHINGTON              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_WASHINGTON PK           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_WELLSHIRE EAST          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_WESTBRIDGE              0.0       0.0       0.0         1.0
# NBHD_1_CN_x_WESTWOOD                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_WHITTIER                0.0       0.0       0.0         1.0
# NBHD_1_CN_x_WILLOW POINT E          0.0       0.0       0.0         1.0
# NBHD_1_CN_x_WLSHR/S HILLS           0.0       0.0       0.0         1.0
# NBHD_1_CN_x_ZUNI PARK               0.0       0.0       0.0         1.0

# %%
# Create feature and target arrays
y = df_inds['SALE_PRICE'].ravel()
X = df_inds.drop(['SALE_PRICE','IMPROVE_VALUE','ASMT_APPR_LAND'], axis=1)

# %%
# now scale the X data
scaler = StandardScaler().fit(X)
X_scaled=scaler.transform(X)

# %%
# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.2, random_state=42)

# %% [markdown]
# ## Code for original runs
# models = [LinearRegression(),
#           RandomForestRegressor(n_estimators=100, max_features='sqrt'),
#           KNeighborsRegressor(n_neighbors=6),
#           SVR(kernel='linear'),
#           LogisticRegression()
#           ]
#
# TestModels = pd.DataFrame()
# tmp = {}
#
#
# for model in models:
#     # get model name
#     m = str(model)
#     print(model)
#     tmp['Model'] = m[:m.index('(')]
#     # fit model on training dataset
#     model.fit(X_train, y_train)
#     # predict prices for test dataset and calculate r^2
#     tmp['R2_Price'] = r2_score(y_test, model.predict(X_test))
#     print(tmp)
#     # write obtained data
#     TestModels = TestModels.append([tmp])
#
# TestModels.set_index('Model', inplace=True)
#
# fig, axes = plt.subplots(ncols=1, figsize=(10, 4))
# TestModels.R2_Price.plot(ax=axes, kind='bar', title='R2_Price')
# plt.show()

# %% [markdown]
# ## Results of original runs
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
# {'Model': 'LinearRegression', 'R2_Price': 0.45273788242807833}
#
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)
#
# {'Model': 'RandomForestRegressor', 'R2_Price': 0.3711615155545427}
#
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                     weights='uniform')
#
# {'Model': 'KNeighborsRegressor', 'R2_Price': 0.2364313459928018}
#
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
#
# {'Model': 'SVR', 'R2_Price': 0.3136196404697671}
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Fit Models with Training Data Set
#
# ### Test : Linear Regression, Random Forest, K Nearest Neighbors, SVR, and Logistic Regression

# %% [markdown]
# ### Model 1: Linear Regression

# %%
lm = LinearRegression()
model1 = lm.fit(X_train,y_train)

# %%
y_pred =model1.predict(X_test)

# show model results without assessed values included
print('explained variance score: ',explained_variance_score(y_test, y_pred))
print('MAE: ',mean_absolute_error(y_test, y_pred))
print('R2 Score: ',r2_score(y_test, y_pred))
print('intercept: ',lm.intercept_)
pd.DataFrame(abs(lm.coef_),X.columns,columns=['Coeff']).sort_values(by=['Coeff'],ascending=False).head(10)
# Out:
# explained variance score:  0.43084269160439426
# MAE:  161026.4060726821
# R2 Score:  0.4308415412063876
# intercept:  312963.7367260646
#                                      Coeff
# AREA_ABG                     101630.955503
# SALE_YEAR                     51989.681367
# NBHD_1_CN_x_COUNTRY CLUB      45979.621083
# RM_AGE                        41388.844287
# NBHD_1_CN_x_WASHINGTON PK     37045.481762
# FBSMT_SQFT                    32115.044170
# NBHD_1_CN_x_HILLTOP           30575.498394
# LAND_SQFT                     25248.868651
# NBHD_1_CN_x_NORTHFIELD        24490.061086
# NBHD_1_CN_x_W WASHINGTON PK   23120.546345

# %%
# show model results with assessed values included
print('explained variance score: ',explained_variance_score(y_test, y_pred))
print('MAE: ',mean_absolute_error(y_test, y_pred))
print('intercept: ',lm.intercept_)
pd.DataFrame(abs(lm.coef_),X.columns,columns=['Coeff']).sort_values(by=['Coeff'],ascending=False)
# Out:
# explained variance score:  0.43084269160439426
# MAE:  161026.4060726821
# intercept:  312963.7367260646
#                                        Coeff
# AREA_ABG                       101630.955503
# SALE_YEAR                       51989.681367
# NBHD_1_CN_x_COUNTRY CLUB        45979.621083
# RM_AGE                          41388.844287
# NBHD_1_CN_x_WASHINGTON PK       37045.481762
# FBSMT_SQFT                      32115.044170
# NBHD_1_CN_x_HILLTOP             30575.498394
# LAND_SQFT                       25248.868651
# NBHD_1_CN_x_NORTHFIELD          24490.061086
# NBHD_1_CN_x_W WASHINGTON PK     23120.546345
# NBHD_1_CN_x_STAPLETON           22565.495960
# NBHD_1_CN_x_POLO CLUB           20750.499266
# NBHD_1_CN_x_N CHERRY CREEK      20210.557925
# NBHD_1_CN_x_N COUNTRY CLUB      20015.331162
# FULL_B                          19913.001449
# NBHD_1_CN_x_PARKWAY             19843.028612
# NBHD_1_CN_x_S COUNTRY CLUB      18923.884171
# NBHD_1_CN_x_UNIVERSITY PK       17767.665677
# NBHD_1_CN_x_CORY MERRILL        17717.100268
# NBHD_1_CN_x_PLATTE PARK         17619.360155
# NBHD_1_CN_x_MONTBELLO           17599.672831
# NBHD_1_CN_x_BONNIE BRAE         17527.563707
# AGE                             16440.662928
# NBHD_1_CN_x_W HIGHLAND          15722.876802
# NBHD_1_CN_x_HIGHLAND            15591.180145
# NBHD_1_CN_x_CHERRY CREEK        15484.677550
# NBHD_1_CN_x_PARK HILL (S)       15172.747696
# NBHD_1_CN_x_N GREEN VALLEY      14730.557834
# NBHD_1_CN_x_LOWRY               14629.037260
# HLF_B                           14622.437089
# NBHD_1_CN_x_GREEN VALLEY        14018.839120
# BED_RMS                         13945.805720
# NBHD_1_CN_x_PARK HILL (N)       13746.547510
# NBHD_1_CN_x_CRESTMOOR           13702.484611
# NBHD_1_CN_x_CONGRESS PARK       13193.669913
# NBHD_1_CN_x_N POLO CLUB         12997.433302
# NBHD_1_CN_x_HALE/MAYFAIR        12539.389487
# NBHD_1_CN_x_UNIVERSITY          11813.892238
# NBHD_1_CN_x_BERKELEY            10988.319473
# NBHD_1_CN_x_BELCARO             10860.955741
# NBHD_1_CN_x_S HALE              10541.167245
# MKT_CLUS                        10436.586608
# NBHD_1_CN_x_S SPEER             10374.720267
# NBHD_1_CN_x_WHITTIER             9709.822084
# GRD_AREA                         9453.985626
# NBHD_1_CN_x_N CONGRESS PK        9331.874855
# NBHD_1_CN_x_N SPEER              8810.838759
# NBHD_1_CN_x_BAKER                8692.081372
# NBHD_1_CN_x_S WASHINGTON PK      8533.672614
# NBHD_1_CN_x_W WASHINGTON PARK    8473.943556
# NBHD_1_CN_x_E HIGHLAND           8265.151288
# NBHD_1_CN_x_N SLOANS LAKE        8116.895450
# BSMT_AREA                        7822.802244
# NBHD_1_CN_x_SLOANS LAKE          7822.385340
# NBHD_1_CN_x_MONTCLAIR            7800.946124
# NBHD_1_CN_x_ROSEDALE             7717.472130
# SALE_MONTHDAY                    7676.067864
# NBHD_1_CN_x_E SLOANS LAKE        7382.764441
# STORY                            7098.828575
# NBHD_1_CN_x_W BAKER              6832.835867
# NBHD_1_CN_x_CAPITOL HILL S       6485.881697
# NBHD_1_CN_x_COLLEGE VIEW         6365.458236
# NBHD_1_CN_x_VIRGINIA VILL        6354.017045
# NBHD_1_CN_x_WLSHR/S HILLS        6331.336577
# NBHD_1_CN_x_STOKES               6276.499337
# NBHD_1_CN_x_CURTIS PARK          6239.676843
# NBHD_1_CN_x_SUNNYSIDE            6194.571981
# NBHD_1_CN_x_PARKFIELD            6097.259818
# NBHD_1_CN_x_W HIGHLAND / HGV     5890.894713
# NBHD_1_CN_x_CHAFFEE PARK         5796.992602
# NBHD_1_CN_x_LINCOLN PARK         5686.755338
# NBHD_1_CN_x_N PARK HILL          5686.402540
# NBHD_1_CN_x_CHEESMAN PARK        5684.815660
# NBHD_1_CN_x_FIVE POINTS          5041.455296
# NBHD_1_CN_x_W CITY PARK          4980.589718
# NBHD_1_CN_x_POLO FIELD           4651.329954
# NBHD_1_CN_x_S CITY PARK          4626.501017
# NBHD_1_CN_x_BEAR VALLEY          4596.394783
# NBHD_1_CN_x_SKYLAND              4565.971103
# NBHD_1_CN_x_UNIVERSITY HLS       4081.898563
# NBHD_1_CN_x_S HARVEY PARK        3946.133648
# NBHD_1_CN_x_RANGE VIEW           3933.248175
# NBHD_1_CN_x_JEFFERSON PARK       3921.887831
# NBHD_1_CN_x_COLE                 3906.996600
# UNITS                            3904.947956
# NBHD_1_CN_x_UNIVERSITY S         3796.932795
# NBHD_1_CN_x_E COLFAX (N)         3415.734487
# NBHD_1_CN_x_FORT LOGAN           3355.671015
# NBHD_1_CN_x_PARK FOREST          3321.257121
# NBHD_1_CN_x_N CAPITOL HILL       3321.233856
# NBHD_1_CN_x_SOUTHMOOR #1         3275.402880
# NBHD_1_CN_x_ZUNI PARK            3204.001972
# NBHD_1_CN_x_CLAYTON              3117.826925
# NBHD_1_CN_x_PINEHURST ES S       3112.509090
# NBHD_1_CN_x_N UNIVERSITY         3024.171473
# NBHD_1_CN_x_EAST BAY             2992.570697
# NBHD_1_CN_x_REGIS                2952.938208
# NBHD_1_CN_x_BARNUM               2941.643924
# NBHD_1_CN_x_E COLFAX (S)         2892.286314
# NBHD_1_CN_x_DARTMOUTH HTS        2820.627573
# NBHD_1_CN_x_VILLAS CHRY HL       2807.950929
# NBHD_1_CN_x_SOUTHMOOR PARK       2585.440724
# NBHD_1_CN_x_CRESTMOOR E          2556.631956
# NBHD_1_CN_x_SWANSEA (N)          2544.198308
# NBHD_1_CN_x_HAMPDEN HTS E        2541.893849
# NBHD_1_CN_x_HILLTOP 6TH AV       2523.934415
# NBHD_1_CN_x_HUTCHINSON HLS       2515.181939
# NBHD_1_CN_x_MAR LEE              2429.304699
# NBHD_1_CN_x_OVERLAND             2412.092511
# NBHD_1_CN_x_SWANSEA (S)          2323.751649
# NBHD_1_CN_x_PINECREST            2312.602029
# NBHD_1_CN_x_ATHMAR PARK          2282.768152
# NBHD_1_CN_x_MONACO PKWY          2274.897388
# NBHD_1_CN_x_HOLLY RIDGE          2253.751119
# NBHD_1_CN_x_WESTWOOD             2218.667615
# NBHD_1_CN_x_VILLA PARK           2204.862938
# NBHD_1_CN_x_GLOBEVILLE           2195.084370
# NBHD_1_CN_x_C GREEN VALLEY       2170.264083
# NBHD_1_CN_x_PINEHURST            2092.584929
# NBHD_1_CN_x_GUN CLUB             2070.063544
# NBHD_1_CN_x_INSPIRATION PT       2020.323240
# NBHD_1_CN_x_HARVEY PARK          1935.634694
# NBHD_1_CN_x_NE PARK HILL         1888.693988
# NBHD_1_CN_x_S. HILLTOP           1868.487899
# NBHD_1_CN_x_CAPITOL HILL         1758.047218
# NBHD_1_CN_x_WELLSHIRE EAST       1543.311702
# NBHD_1_CN_x_SEVEN SPRINGS        1477.207478
# NBHD_1_CN_x_AVONDALE             1453.160702
# NBHD_1_CN_x_GODSMAN              1416.492810
# NBHD_1_CN_x_CHERRY POINT         1396.234889
# NBHD_1_CN_x_RUBY HILL            1311.795618
# NBHD_1_CN_x_SUMMERFIELD          1252.314825
# NBHD_1_CN_x_S CHERRY CREEK       1245.580965
# NBHD_1_CN_x_CRESTRIDGE           1243.822262
# NBHD_1_CN_x_HILLTOP DOWNS        1224.139758
# NBHD_1_CN_x_ARAPAHOE SQUARE      1211.446073
# NBHD_1_CN_x_E HARVEY PARK        1208.109235
# NBHD_1_CN_x_VALVERDE             1136.729838
# NBHD_1_CN_x_CHERMONT             1094.964908
# NBHD_1_CN_x_GRANT RN/MARST       1036.978378
# NBHD_1_CN_x_INDIAN CREEK          985.542637
# NBHD_1_CN_x_CORNERSTONE           960.210043
# NBHD_1_CN_x_PINEHURST ESTA        935.431667
# NBHD_1_CN_x_BISCAYNE              871.040056
# NBHD_1_CN_x_CIVIC CENTER          783.750767
# NBHD_1_CN_x_W COLFAX              737.869562
# NBHD_1_CN_x_BELMONT HTS           719.788369
# NBHD_1_CN_x_GOLDSMITH             716.177495
# NBHD_1_CN_x_RIVER NORTH           670.151757
# NBHD_1_CN_x_CENTRAL PARK          646.971657
# NBHD_1_CN_x_THOMAS PLACE          634.909140
# NBHD_1_CN_x_GOLDSMITH  W          564.041433
# NBHD_1_CN_x_HUTCH/WILLOW P        562.925610
# NBHD_1_CN_x_POPLAR COVE           546.585061
# NBHD_1_CN_x_HAMPDEN HTS W         480.896437
# NBHD_1_CN_x_CREEKVW/SUNSET        480.752308
# NBHD_1_CN_x_LYNWOOD               456.705196
# NBHD_1_CN_x_HOLLY HILLS           327.874378
# NBHD_1_CN_x_VIRGINIA VALE         275.838603
# NBHD_1_CN_x_BREAKERS              275.029907
# NBHD_1_CN_x_PARKWEST              267.659274
# NBHD_1_CN_x_OVERLOOK              265.422920
# NBHD_1_CN_x_WASHINGTON            180.767613
# NBHD_1_CN_x_PARK VISTA            177.338931
# NBHD_1_CN_x_PINE VALLEY           128.192497
# NBHD_1_CN_x_WESTBRIDGE            117.987945
# NBHD_1_CN_x_SOUTH PLATTE          110.109451
# NBHD_1_CN_x_SUN VALLEY            108.805621
# NBHD_1_CN_x_WILLOW POINT E         98.008969
# NBHD_1_CN_x_SWANSEA                58.988904
# NBHD_1_CN_x_GLENBROOK              51.944246
# NBHD_1_CN_x_TAMARAC HILLS          10.043717
# NBHD_1_CN_x_PINE RIDGE              1.848205

# %%
for model in models:
    # get model name
    m = str(model)
    print(model)
    tmp['Model'] = m[:m.index('(')]
    # fit model on training dataset
    model.fit(X_train, y_train)
    # predict prices for test dataset and calculate r^2
    tmp['R2_Price'] = r2_score(y_test, model.predict(X_test))
    print(tmp)
    # write obtained data
    TestModels = TestModels.append([tmp])
 
TestModels.set_index('Model', inplace=True)
 
fig, axes = plt.subplots(ncols=1, figsize=(10, 4))
TestModels.R2_Price.plot(ax=axes, kind='bar', title='R2_Price')
plt.show()

# %%
TestModels.set_index('Model', inplace=True)
 
fig, axes = plt.subplots(ncols=1, figsize=(10, 4))
TestModels.R2_Price.plot(ax=axes, kind='bar', title='R2_Price')
plt.show()

# %% [markdown]
# ### Model 2: Random Forest

# %%
rf = RandomForestRegressor(n_estimators=100, max_features='sqrt')
model2 = rf.fit(X_train,y_train)

# %%
y_pred =model2.predict(X_test)

# show model results without assessed values included
print('explained variance score: ',explained_variance_score(y_test, y_pred))
print('MAE: ',mean_absolute_error(y_test, y_pred))
print('R2 score is: ',r2_score(y_test, y_pred))
# Out:
# explained variance score:  0.40940855938697407
# MAE:  149111.62126241068
# R2 score is:  0.4091512560234932

# %% [markdown]
# ### Model 3: k nearest neighbors

# %%
kn = KNeighborsRegressor(n_neighbors=6)
model3 = kn.fit(X_train,y_train)

# %%
y_pred =model3.predict(X_test)
# show model results without assessed values included
print('explained variance score: ',explained_variance_score(y_test, y_pred))
print('MAE: ',mean_absolute_error(y_test, y_pred))
print('R2 score is: ',r2_score(y_test, y_pred))
# Out:
# explained variance score:  0.2665056616452648
# MAE:  162448.31895221604
# R2 score is:  0.2665034784018232

# %% [markdown]
# ### Model 4: SVR

# %%
sv = SVR(kernel='linear')
model4 = sv.fit(X_train,y_train)

# %%
# show model results without assessed values included
y_pred =model4.predict(X_test)

print('explained variance score: ',explained_variance_score(y_test, y_pred))
print('MAE: ',mean_absolute_error(y_test, y_pred))
# Out:
# explained variance score:  0.26435270260857247
# MAE:  175630.75694343183

# %%
print('R2 score is: ',r2_score(y_test, y_pred))
# Out:
# R2 score is:  0.2628601075556224
